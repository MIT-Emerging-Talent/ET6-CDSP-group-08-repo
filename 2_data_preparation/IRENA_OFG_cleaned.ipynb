# %% [markdown]
# # Load the dataset

# %%
import pandas as pd

raw_df = pd.read_excel(
    "../1_datasets/raw_data/IRENA_OFGStats.raw.xlsx", sheet_name="data"
)
df = raw_df.copy()
df.head()
# Out:
#    Region       UN Sub-region Country IRENA Label ISO Code               Flow  \
# 0  Africa  Sub-Saharan Africa  Angola      Angola      AGO  Off-grid capacity
# 1  Africa  Sub-Saharan Africa  Angola      Angola      AGO  Off-grid capacity
# 2  Africa  Sub-Saharan Africa  Angola      Angola      AGO  Off-grid capacity
# 3  Africa  Sub-Saharan Africa  Angola      Angola      AGO  Off-grid capacity
# 4  Africa  Sub-Saharan Africa  Angola      Angola      AGO  Off-grid capacity
#
#   Group Technology     Sub-Technology               Technology  Product Code  \
# 0     Solar energy  Solar PV (Others)  Other off-grid solar PV       24129.0
# 1     Solar energy  Solar PV (Others)  Other off-grid solar PV       24129.0
# 2     Solar energy  Solar PV (Others)  Other off-grid solar PV       24129.0
# 3     Solar energy  Solar PV (Others)  Other off-grid solar PV       24129.0
# 4     Solar energy  Solar PV (Others)  Other off-grid solar PV       24129.0
#
#   DataType  Value Unit  Year  Ptype             Publication
# 0  ELECCAP    0.0   MW  2000    220  2024 OFG RE Statistics
# 1  ELECCAP    0.0   MW  2001    220  2024 OFG RE Statistics
# 2  ELECCAP    0.0   MW  2002    220  2024 OFG RE Statistics
# 3  ELECCAP    0.0   MW  2003    220  2024 OFG RE Statistics
# 4  ELECCAP    0.0   MW  2004    220  2024 OFG RE Statistics

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52343 entries, 0 to 52342
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Region            52343 non-null  object
#  1   UN Sub-region     52343 non-null  object
#  2   Country           52343 non-null  object
#  3   IRENA Label       52343 non-null  object
#  4   ISO Code          52343 non-null  object
#  5   Flow              52343 non-null  object
#  6   Group Technology  52343 non-null  object
#  7   Sub-Technology    52343 non-null  object
#  8   Technology        52343 non-null  object
#  9   Product Code      51205 non-null  float64
#  10  DataType          52343 non-null  object
#  11  Value             52321 non-null  float64
#  12  Unit              52343 non-null  object
#  13  Year              52343 non-null  int64
#  14  Ptype             52343 non-null  int64
#  15  Publication       52343 non-null  object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 6.4+ MB
# (52343, 16)

# %%
df.isnull().sum()
# Out:
# Region                 0
# UN Sub-region          0
# Country                0
# IRENA Label            0
# ISO Code               0
# Flow                   0
# Group Technology       0
# Sub-Technology         0
# Technology             0
# Product Code        1138
# DataType               0
# Value                 22
# Unit                   0
# Year                   0
# Ptype                  0
# Publication            0
# dtype: int64

# %% [markdown]
# - **It's clear that there are a lot of null values in the product Code but the column itself is not relevant to our study so it will be dropped along with: UN Sub-region, IRENA Label, Ptype, and publication**

# %%
df.drop(
    [
        "UN Sub-region",
        "IRENA Label",
        "Ptype",
        "Publication",
        "Product Code",
        "DataType",
    ],
    axis=1,
    inplace=True,
)

# %%
df.head()
# Out:
#    Region Country ISO Code               Flow Group Technology  \
# 0  Africa  Angola      AGO  Off-grid capacity     Solar energy
# 1  Africa  Angola      AGO  Off-grid capacity     Solar energy
# 2  Africa  Angola      AGO  Off-grid capacity     Solar energy
# 3  Africa  Angola      AGO  Off-grid capacity     Solar energy
# 4  Africa  Angola      AGO  Off-grid capacity     Solar energy
#
#       Sub-Technology               Technology  Value Unit  Year
# 0  Solar PV (Others)  Other off-grid solar PV    0.0   MW  2000
# 1  Solar PV (Others)  Other off-grid solar PV    0.0   MW  2001
# 2  Solar PV (Others)  Other off-grid solar PV    0.0   MW  2002
# 3  Solar PV (Others)  Other off-grid solar PV    0.0   MW  2003
# 4  Solar PV (Others)  Other off-grid solar PV    0.0   MW  2004

# %% [markdown]
# - **Now, we should handle the 22 missing values in the "Value" Column**

# %%
missing_rows = df[df["Value"].isnull()]
missing_rows
# Out:
#                                   Region  \
# 39940  Central America and the Caribbean
# 39946  Central America and the Caribbean
# 39957  Central America and the Caribbean
# 39971  Central America and the Caribbean
# 40021  Central America and the Caribbean
# 40035  Central America and the Caribbean
# 40082                      South America
# 40089                      South America
# 40141                             Africa
# 40169                             Africa
# 40209                        Middle East
# 40283                            Oceania
# 40293                            Oceania
# 40303                            Oceania
# 40309                            Oceania
# 40330                            Oceania
# 40352                            Oceania
# 40427                               Asia
# 40522                               Asia
# 43089                             Africa
# 43157                             Africa
# 43308                             Africa
#
#                                       Country ISO Code               Flow  \
# 39940                           Bahamas (the)      BHS  Off-grid capacity
# 39946                                  Belize      BLZ  Off-grid capacity
# 39957                              Costa Rica      CRI  Off-grid capacity
# 39971                                Dominica      DMA  Off-grid capacity
# 40021                               Nicaragua      NIC  Off-grid capacity
# 40035                             Puerto Rico      PRI  Off-grid capacity
# 40082                                  Brazil      BRA  Off-grid capacity
# 40089                                   Chile      CHL  Off-grid capacity
# 40141                                   Egypt      EGY  Off-grid capacity
# 40169                             Sudan (the)      SDN  Off-grid capacity
# 40209                                  Jordan      JOR  Off-grid capacity
# 40283                                Kiribati      KIR  Off-grid capacity
# 40293                  Marshall Islands (the)      MHL  Off-grid capacity
# 40303                                   Nauru      NRU  Off-grid capacity
# 40309                                   Palau      PLW  Off-grid capacity
# 40330                                   Samoa      WSM  Off-grid capacity
# 40352                                   Tonga      TON  Off-grid capacity
# 40427  Lao People's Democratic Republic (the)      LAO  Off-grid capacity
# 40522                                  Bhutan      BTN  Off-grid capacity
# 43089                              Cabo Verde      CPV  Off-grid capacity
# 43157                       Equatorial Guinea      GNQ  Off-grid capacity
# 43308                              Mauritania      MRT  Off-grid capacity
#
#       Group Technology        Sub-Technology  \
# 39940     Solar energy  Solar lights and SHS
# 39946     Solar energy  Solar lights and SHS
# 39957     Solar energy  Solar lights and SHS
# 39971     Solar energy  Solar lights and SHS
# 40021     Solar energy  Solar lights and SHS
# 40035     Solar energy  Solar lights and SHS
# 40082     Solar energy  Solar lights and SHS
# 40089     Solar energy  Solar lights and SHS
# 40141     Solar energy  Solar lights and SHS
# 40169     Solar energy  Solar lights and SHS
# 40209     Solar energy  Solar lights and SHS
# 40283     Solar energy  Solar lights and SHS
# 40293     Solar energy  Solar lights and SHS
# 40303     Solar energy  Solar lights and SHS
# 40309     Solar energy  Solar lights and SHS
# 40330     Solar energy  Solar lights and SHS
# 40352     Solar energy  Solar lights and SHS
# 40427     Solar energy  Solar lights and SHS
# 40522     Solar energy  Solar lights and SHS
# 43089     Solar energy  Solar lights and SHS
# 43157     Solar energy  Solar lights and SHS
# 43308     Solar energy  Solar lights and SHS
#
#                                       Technology  Value Unit  Year
# 39940  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 39946  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 39957  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 39971  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40021  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40035  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40082  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40089  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40141  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40169  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40209  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40283  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40293  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40303  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40309  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40330  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40352  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40427  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 40522  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 43089  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 43157  Solar lights and solar home systems (SHS)    NaN   MW  2023
# 43308  Solar lights and solar home systems (SHS)    NaN   MW  2023

# %% [markdown]
# - **So, it's apparent that most of the missing values here are from countries out of our scope, so it's better to just fill the null values with zeros**

# %% [markdown]
# # Filling the missing values with zeros

# %%
df2 = df.fillna(value=0)
df2.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# - Now, let's checkup the year range, our research study is from 2010 onward

# %%
df2["Year"].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023], dtype=int64)

# %%
df2 = df2[df2["Year"] >= 2010]
df2["Year"].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021, 2022, 2023], dtype=int64)

# %% [markdown]
# - **Now, we can add a conflict status column to the dataset to present whether a country experienced conflicts in the predefined period or not.**

# %%
conflict_countries = [
    "Syria",
    "Iraq",
    "Sudan (the)",
    "South Sudan",
    "Palestine",
    "Mali",
    "Ethiopia",
    "Ukraine",
    "Yemen",
    "Libya",
    "Afghanistan",
    "Nigeria",
    "Central African Republic",
    "Somalia",
    "Pakistan",
    "Mozambique",
    "Myanmar",
    "Chad",
    "Democratic Republic of the Congo",
]
df2["Conflict Status"] = df2["Country"].apply(
    lambda x: "Conflict" if x in conflict_countries else "No Conflict"
)
df2.sample(10)
# Out:
#             Region                     Country ISO Code  \
# 50824       Africa                    Djibouti      DJI
# 34562       Africa                     Burundi      BDI
# 42675       Africa                        Chad      TCD
# 49955       Africa                     Senegal      SEN
# 41546      Oceania                     Vanuatu      VUT
# 35737       Africa                    Zimbabwe      ZWE
# 50111       Africa                     Burundi      BDI
# 47027  Middle East  Iran (Islamic Republic of)      IRN
# 41786         Asia                    Thailand      THA
# 50094       Africa                     Somalia      SOM
#
#                              Flow Group Technology  \
# 50824           Off-grid capacity     Solar energy
# 34562  Off-grid biogas production        Bioenergy
# 42675           Off-grid capacity     Solar energy
# 49955           Off-grid capacity     Solar energy
# 41546           Off-grid capacity     Solar energy
# 35737      Off-grid energy access     Solar energy
# 50111           Off-grid capacity     Solar energy
# 47027           Off-grid capacity     Solar energy
# 41786           Off-grid capacity     Solar energy
# 50094           Off-grid capacity     Solar energy
#
#                      Sub-Technology  \
# 50824             Solar PV (Others)
# 34562             Biogas production
# 42675                  Solar lights
# 49955    Solar PV (Public lighting)
# 41546            Solar home systems
# 35737                  Solar lights
# 50111  Solar PV (Commercial/Public)
# 47027      Solar PV (Not specified)
# 41786            Solar home systems
# 50094      Solar PV (Multi-purpose)
#
#                                               Technology       Value  \
# 50824                            Other off-grid solar PV    0.024500
# 34562                            Total biogas production    2.440000
# 42675                               Solar lights (<11 W)    0.062080
# 49955  Other off-grid solar PV (of which public light...    0.042500
# 41546                   Solar home systems (SHS 11-50 W)    0.472390
# 35737        Number of people using solar lights (<11 W)  596.330586
# 50111  Other off-grid solar PV (of which commercial/p...    0.003000
# 47027   Other off-grid solar PV (of which not specified)    0.378000
# 41786                   Solar home systems (SHS 11-50 W)    0.023280
# 50094   Other off-grid solar PV (of which multi-purpose)    3.500000
#
#             Unit  Year Conflict Status
# 50824         MW  2018     No Conflict
# 34562   1,000 m3  2020     No Conflict
# 42675         MW  2021        Conflict
# 49955         MW  2022     No Conflict
# 41546         MW  2022     No Conflict
# 35737  Thousands  2019     No Conflict
# 50111         MW  2015     No Conflict
# 47027         MW  2013     No Conflict
# 41786         MW  2017     No Conflict
# 50094         MW  2023        Conflict

# %% [markdown]
# - **let's check if all the unit in the `Unit` column are the same**

# %%
df2["Unit"].unique()
# Out:
# array(['MW', 'Thousands', '1,000 m3'], dtype=object)

# %% [markdown]
# - Hmm, that's interesting, we have to somehow standardize the dataset

# %%
df2[df2["Unit"] == "1,000 m3"]
# Out:
#        Region   Country ISO Code                        Flow Group Technology  \
# 11281  Africa   Burundi      BDI  Off-grid biogas production        Bioenergy
# 11282  Africa   Burundi      BDI  Off-grid biogas production        Bioenergy
# 11283  Africa   Burundi      BDI  Off-grid biogas production        Bioenergy
# 11284  Africa   Burundi      BDI  Off-grid biogas production        Bioenergy
# 11285  Africa   Burundi      BDI  Off-grid biogas production        Bioenergy
# ...       ...       ...      ...                         ...              ...
# 34763  Africa  Zimbabwe      ZWE  Off-grid biogas production        Bioenergy
# 34764  Africa  Zimbabwe      ZWE  Off-grid biogas production        Bioenergy
# 34765  Africa  Zimbabwe      ZWE  Off-grid biogas production        Bioenergy
# 34766  Africa  Zimbabwe      ZWE  Off-grid biogas production        Bioenergy
# 34767  Africa  Zimbabwe      ZWE  Off-grid biogas production        Bioenergy
#
#           Sub-Technology                         Technology      Value  \
# 11281  Biogas production  Production of biogas for industry     0.0000
# 11282  Biogas production  Production of biogas for industry     0.0000
# 11283  Biogas production  Production of biogas for industry     0.0000
# 11284  Biogas production  Production of biogas for industry     0.0000
# 11285  Biogas production  Production of biogas for industry     0.0000
# ...                  ...                                ...        ...
# 34763  Biogas production            Total biogas production  1148.0810
# 34764  Biogas production            Total biogas production  1142.4995
# 34765  Biogas production            Total biogas production  1135.5455
# 34766  Biogas production            Total biogas production  1055.3000
# 34767  Biogas production            Total biogas production  1055.3000
#
#            Unit  Year Conflict Status
# 11281  1,000 m3  2010     No Conflict
# 11282  1,000 m3  2011     No Conflict
# 11283  1,000 m3  2012     No Conflict
# 11284  1,000 m3  2013     No Conflict
# 11285  1,000 m3  2014     No Conflict
# ...         ...   ...             ...
# 34763  1,000 m3  2019     No Conflict
# 34764  1,000 m3  2020     No Conflict
# 34765  1,000 m3  2021     No Conflict
# 34766  1,000 m3  2022     No Conflict
# 34767  1,000 m3  2023     No Conflict
#
# [2702 rows x 11 columns]

# %% [markdown]
# - The `1000 m3` unit is appeared to be primarily used for `Biogass` technology, which is irrelevant to us

# %%
df2.groupby(["Flow", "Unit"])["Technology"].count()
# Out:
# Flow                        Unit
# Off-grid biogas production  1,000 m3      2702
# Off-grid capacity           MW           19658
# Off-grid energy access      Thousands     8526
# Name: Technology, dtype: int64

# %%
df2 = df2[~df2["Sub-Technology"].str.contains("biogas", case=False, na=False)]
df2 = df2[df2["Group Technology"] != "Bioenergy"]

# %%
df2.groupby(["Flow", "Unit"])["Technology"].count()
# Out:
# Flow                    Unit
# Off-grid capacity       MW           18762
# Off-grid energy access  Thousands     7714
# Name: Technology, dtype: int64

# %%
df2.sample(10)
# Out:
#                                   Region                           Country  \
# 39965  Central America and the Caribbean                              Cuba
# 51766                        Middle East                              Iraq
# 47667                               Asia                       Afghanistan
# 50292                             Africa                            Angola
# 44923                               Asia                 Philippines (the)
# 27824                             Africa                           Morocco
# 2728                              Africa                             Benin
# 39673                             Africa                           Liberia
# 47798                               Asia                        Bangladesh
# 49168                      South America  Bolivia (Plurinational State of)
#
#       ISO Code               Flow                   Group Technology  \
# 39965      CUB  Off-grid capacity                       Solar energy
# 51766      IRQ  Off-grid capacity                       Solar energy
# 47667      AFG  Off-grid capacity                       Solar energy
# 50292      AGO  Off-grid capacity                       Solar energy
# 44923      PHL  Off-grid capacity                       Solar energy
# 27824      MAR  Off-grid capacity                       Solar energy
# 2728       BEN  Off-grid capacity                       Solar energy
# 39673      LBR  Off-grid capacity  Hydropower (excl. Pumped Storage)
# 47798      BGD  Off-grid capacity                       Solar energy
# 49168      BOL  Off-grid capacity                       Solar energy
#
#                      Sub-Technology  \
# 39965          Solar lights and SHS
# 51766             Solar PV (Others)
# 47667    Solar PV (Public lighting)
# 50292             Solar PV (Health)
# 44923                   Solar pumps
# 27824                 Solar cookers
# 2728               Solar mini-grids
# 39673                    Hydropower
# 47798  Solar PV (Commercial/Public)
# 49168  Solar PV (Commercial/Public)
#
#                                               Technology      Value Unit  \
# 39965          Solar lights and solar home systems (SHS)   0.858615   MW
# 51766                            Other off-grid solar PV  37.600000   MW
# 47667  Other off-grid solar PV (of which public light...   0.093210   MW
# 50292          Other off-grid solar PV (of which health)   0.021125   MW
# 44923                  Solar pumps (public water supply)   0.007600   MW
# 27824                                      Solar cookers   0.092940   MW
# 2728                                    Solar mini-grids   0.000000   MW
# 39673                                         Hydropower   4.860000   MW
# 47798  Other off-grid solar PV (of which commercial/p...   2.719755   MW
# 49168  Other off-grid solar PV (of which commercial/p...   0.000080   MW
#
#        Year Conflict Status
# 39965  2021     No Conflict
# 51766  2021        Conflict
# 47667  2022        Conflict
# 50292  2015     No Conflict
# 44923  2016     No Conflict
# 27824  2019     No Conflict
# 2728   2010     No Conflict
# 39673  2013     No Conflict
# 47798  2016     No Conflict
# 49168  2013     No Conflict

# %%
df2["Sub-Technology"].unique()
# Out:
# array(['Solar PV (Others)', 'Solar PV (Health)',
#        'Solar PV (Commercial/Public)', 'Solar PV (Education)',
#        'Solar PV (Not specified)', 'Solar PV (Industry)',
#        'Solar PV (Tourism)', 'Solar PV (Public lighting)',
#        'Solar PV (Communication)', 'Solar PV (Residential)',
#        'Solar PV (Agriculture)', 'Solar PV (Multi-purpose)',
#        'Solar mini-grids', 'Solar lights', 'Solar pumps',
#        'Solar home systems', 'Onshore wind energy', 'Hydropower',
#        'Solar cookers', 'Solar lights and SHS'], dtype=object)

# %% [markdown]
# - **Now, The resultant dataset will be saved to "cleaned_data" sub-folder in the "1_dataset" folder**

# %%
df2.to_excel(
    "../1_datasets/cleaned_data/IRENA_OFGStats.cleaned.xlsx",
    sheet_name="Cleaned_data",
    index=False,
)
